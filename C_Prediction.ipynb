# %%
import pandas as pd
import pickle

# %%
model = pickle.load(open("model.pkl", "rb"))
print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully

# %% [markdown]
# ## New Customer Data
#
# Agar tumne EDA me RowNumber, CustomerId aur Surname drop kiye the, to ye code use karo:

# %%
new_customer = pd.DataFrame({
    "CreditScore": [600],
    "Geography": ["France"],
    "Gender": ["Male"],
    "Age": [40],
    "Tenure": [5],
    "Balance": [60000],
    "NumOfProducts": [2],
    "HasCrCard": [1],
    "IsActiveMember": [1],
    "EstimatedSalary": [50000]
})

# %% [markdown]
# ## Prediction

# %%
prediction = model.predict(new_customer)

print(prediction)
# Out:
# [0]

# %%
prediction = model.predict(new_customer)

if prediction[0] == 1:
    print("Customer Will Churn")
else:
    print("Customer Will Not Churn")
# Out:
# Customer Will Not Churn
